# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from pandas.tools.plotting import scatter_matrix

plt.rcParams['figure.figsize'] = (16, 12)
pd.set_option('display.mpl_style', 'default')
pd.set_option('display.width',500)
pd.set_option('display.max_columns',100)

# %%
# Acquires and imports the data
OnlineBackup=pd.read_csv('OnlineBackup.csv',header=0)

print "%i Rows and %i Columns" %OnlineBackup.shape
OnlineBackup.head()
OnlineBackup.describe()
# Out:
# 621 Rows and 18 Columns
#             Click  UniqueClick       Price        Rank      Rating         See  FreeVersion         Mac  Windowsphone       Linux        Disk     Sharing    Explorer      Folder      Search     Version      Backup
# count  621.000000   621.000000  621.000000  621.000000  621.000000  621.000000   621.000000  621.000000    621.000000  621.000000  621.000000  621.000000  621.000000  621.000000  621.000000  621.000000  621.000000
# mean    11.288245    10.167472   61.683011    4.971014    0.333333    0.888889     0.666667    0.888889      0.444444    0.444444    0.666667    0.666667    0.555556    0.666667    0.888889    0.888889    0.777778
# std     18.618037    16.348453   28.133900    2.617398    0.471785    0.314523     0.471785    0.314523      0.497305    0.497305    0.471785    0.471785    0.497305    0.471785    0.314523    0.314523    0.416075
# ...

# %%
OnlineBackup.hist()
# Out:
# array([[<matplotlib.axes.AxesSubplot object at 0x109597d50>,
# ...
#         <matplotlib.axes.AxesSubplot object at 0x10ce43b50>]], dtype=object)

# %%
scatter_matrix(OnlineBackup, alpha=0.2,figsize=(20, 20), diagonal='kde')
# Out:
# array([[<matplotlib.axes.AxesSubplot object at 0x11845c4d0>,
# ...
#         <matplotlib.axes.AxesSubplot object at 0x11cdc3150>]], dtype=object)

# %%
# Acquires and imports the data
print "%i Rows and %i Columns" %OnlineBackup.shape
OnlineBackup.head()
OnlineBackup.describe()
# finding correlation
fig, axs = plt.subplots(1, 2)
OnlineBackup.plot(kind='scatter', y='Click', x='Price',lw=0,alpha=.08,color='k',ax=axs[0],figsize=(10, 5))
OnlineBackup.plot(kind='scatter', y='Click', x='Rank', lw=0,alpha=.08,color='k', ax=axs[1],figsize=(10, 5))

fig, axs = plt.subplots(1, 2)
OnlineBackup.plot(kind='scatter', y='Click', x='Rating',lw=0,alpha=.08,color='k',ax=axs[0],figsize=(10, 5))
OnlineBackup.plot(kind='scatter', y='Click', x='See', lw=0,alpha=.08,color='k', ax=axs[1],figsize=(10, 5))

fig, axs = plt.subplots(1, 2)
OnlineBackup.plot(kind='scatter', y='Click', x='FreeVersion',lw=0,alpha=.08,color='k',ax=axs[0],figsize=(10, 5))
OnlineBackup.plot(kind='scatter', y='Click', x='Mac', lw=0,alpha=.08,color='k', ax=axs[1],figsize=(10, 5))

fig, axs = plt.subplots(1, 2)
OnlineBackup.plot(kind='scatter', y='Click', x='Windowsphone',lw=0,alpha=.08,color='k',ax=axs[0],figsize=(10, 5))
OnlineBackup.plot(kind='scatter', y='Click', x='Linux', lw=0,alpha=.08,color='k', ax=axs[1],figsize=(10, 5))
# Out:
# 621 Rows and 18 Columns

# %%
# Generate the Correlation matrix
print(OnlineBackup.corr())
# Out:
#                  Click  UniqueClick     Price      Rank        Rating       See   FreeVersion       Mac  Windowsphone     Linux          Disk       Sharing  Explorer        Folder    Search   Version    Backup
# Click         1.000000     0.997970 -0.046931 -0.554389  5.373466e-01  0.208475  6.475826e-02  0.106839      0.399696  0.247792  2.263479e-01  8.146809e-02 -0.022898  1.371063e-02  0.208475  0.106839  0.149865
# UniqueClick   0.997970     1.000000 -0.046710 -0.559968  5.404263e-01  0.213787  6.329254e-02  0.108706      0.409820  0.250318  2.364409e-01  7.395748e-02 -0.028722  3.903505e-03  0.213787  0.108706  0.147275
# Price        -0.046931    -0.046710  1.000000 -0.276180  1.912262e-03 -0.052911  7.774170e-02  0.587255     -0.415711  0.538096  2.827240e-02  7.687893e-02  0.445165  5.036565e-01 -0.052911  0.587255  0.127170
# ...

# %%
import numpy as np
import pandas as pd
from sklearn import cross_validation
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
from IPython.core.pylabtools import figsize

from sklearn.cross_validation import train_test_split
from sklearn.linear_model import Ridge
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline

OnlineBackup.columns
Y=OnlineBackup['Click']
X=OnlineBackup[['Price', 'Rank','Rating','See','FreeVersion','Mac','Windowsphone','Linux','Disk','Sharing','Explorer','Folder','Search','Version','Backup']]
#lm=LinearRegression()
#lm.fit(X,Y)

# %%
# User F selection to choose the attribute I want to include
from sklearn.feature_selection import f_regression
p_values, f_scores = f_regression(X,Y)
print p_values
print f_scores

feature_scores = pd.DataFrame([p_values, f_scores],columns=(X.columns),index=['f_scores', 'p_values']).T
feature_scores.sort_index(by='f_scores', ascending=False)
# Out:
# [  1.36637999e+00   2.74665597e+02   2.51288233e+02   2.81252625e+01
#    2.60678989e+00   7.14718596e+00   1.17691376e+02   4.04934793e+01
#    3.34259681e+01   4.13578301e+00   3.24718360e-01   1.16382391e-01
#    2.81252625e+01   7.14718596e+00   1.42219367e+01]
# [  2.42884777e-01   2.51260262e-51   9.47287298e-48   1.58489939e-07
#    1.06916550e-01   7.70621663e-03   3.19119382e-25   3.84002020e-10
#    1.17455785e-08   4.24116207e-02   5.68992532e-01   7.33107455e-01
#    1.58489939e-07   7.70621663e-03   1.78043569e-04]
#                 f_scores      p_values
# Rank          274.665597  2.512603e-51
# Rating        251.288233  9.472873e-48
# Windowsphone  117.691376  3.191194e-25
# Linux          40.493479  3.840020e-10
# Disk           33.425968  1.174558e-08
# See            28.125262  1.584899e-07
# Search         28.125262  1.584899e-07
# Backup         14.221937  1.780436e-04
# Mac             7.147186  7.706217e-03
# Version         7.147186  7.706217e-03
# ...

# %%
print lm.intercept_
print lm.coef_
zip(X.columns,lm.coef_)
#print lm.score(X,Y)
# Out:
# 76.915080992
# [   0.51948163  -14.31610809   26.70057302   -4.08964497   56.29066243
#   -16.77672509   -1.06824862 -124.73935954  -10.07791758  -40.02905966
#   105.54888449  -52.71613978   -4.08964497  -16.77672509   38.55727412]
# [('Price', 0.51948163152568649),
#  ('Rank', -14.316108093177487),
#  ('Rating', 26.700573018543817),
#  ('See', -4.0896449669799857),
#  ('FreeVersion', 56.290662433709102),
#  ('Mac', -16.776725091163563),
#  ('Windowsphone', -1.0682486202500279),
#  ('Linux', -124.73935954423359),
#  ('Disk', -10.077917577536207),
#  ('Sharing', -40.029059657834459),
#  ('Explorer', 105.54888449420493),
#  ('Folder', -52.716139782014416),
#  ('Search', -4.0896449669799999),
#  ('Version', -16.77672509116363),
#  ('Backup', 38.557274119402209)]

# %%
# Based on f_scores and p_values choose the best attributes to include in the regression
import numpy as np
import pandas as pd
from sklearn import cross_validation as cv
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
from IPython.core.pylabtools import figsize

from sklearn.cross_validation import train_test_split
from sklearn.linear_model import Ridge
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline

Y=OnlineBackup['Click']
X=OnlineBackup[['Rank','Rating','Windowsphone','Linux','Disk','See','Search']]

X_train, X_test, Y_train, Y_test = cv.train_test_split(X, Y, test_size=.3)
lm=LinearRegression()
lm.fit(X_train,Y_train)

print lm.intercept_
print lm.coef_
zip(X.columns,lm.coef_)
print lm.score(X_train,Y_train),lm.score(X_test,Y_test)
# Out:
# 11.056140518
# [-2.01972486  3.56785603  8.91638731  3.35466079 -3.77963106  2.81578455
#   2.81578455]
# 0.351375536095 0.368782580365

# %%
# The clicks decreases with the decreased rank. 
# Rating "EC, Editor's choice" also inlfuenced the clicks by +3.6 clicks with tag of 'EC'
# Among other attributes, whether it has "Windows Phone Client" influcenc the numbers of clicks the most
